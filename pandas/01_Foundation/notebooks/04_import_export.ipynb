# %% [markdown]
# ### **🧭 Stage 1 → Lesson 4: Importing & Exporting Data (I/O Operations)**
#
# **🎯 Objective**
#
# By the end of this lesson, you’ll:
#
# - Load data from various sources (CSV, Excel, JSON, SQL)
# - Handle file paths, encodings, missing headers
# - Export clean datasets in multiple formats
#  -Work with real data import/export patterns used in ETL

# %% [markdown]
# #### **🧱 Pandas I/O Ecosystem Overview**
#
# Pandas supports reading and writing 40+ data formats through its I/O API.
#
# | **Format**        | **Read Function**    | **Write Function**   |
# |-------------------|----------------------|----------------------|
# | CSV               | `read_csv()`         | `to_csv()`           |
# | Excel             | `read_excel()`       | `to_excel()`         |
# | JSON              | `read_json()`        | `to_json()`          |
# | Parquet           | `read_parquet()`     | `to_parquet()`       |
# | SQL               | `read_sql()`         | `to_sql()`           |
# | Clipboard         | `read_clipboard()`   | —                    |

# %% [markdown]
# **Importing necessary libraries**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **🧩 Reading CSV Files**

# %%
# Since pandas is being used to handle the data, we assume it has already been imported. 
# If not, you can import it like this:
# import pandas as pd

# Step 2: Reading data from a CSV file
# pd.read_csv() is used to read a CSV file and load its contents into a pandas DataFrame.
# The 'r' before the file path is used to indicate a raw string, which ensures that backslashes in file paths are interpreted correctly.
df_SalesData = pd.read_csv(r"C:\Users\dhira\Desktop\GEN_AI_PROJECT\pandas\01_Foundation\dataset\raw\sample_sales.csv")

# Step 3: Displaying the first few rows of the DataFrame
# .head() is a pandas function that returns the first 5 rows of the DataFrame by default. 
# This is useful for quickly inspecting the structure of the data, ensuring it's loaded correctly.
print(df_SalesData.head())
# Out:
#          Date     Product  Units  UnitPrice  Revenue
# 0  2024-01-01     Monitor     46       1999    91954
# 1  2024-01-02    Keyboard      8       9999    79992
# 2  2024-01-03  Headphones     25        999    24975
# 3  2024-01-04     Monitor     35      14999   524965
# 4  2024-01-05  Headphones     25       2999    74975

# %% [markdown]
# **Parameters for `read_csv()` and Other I/O Functions**
# | **Parameter**     | **Description**                              |
# |-------------------|----------------------------------------------|
# | `sep`             | Specify separator (default `,`)              |
# | `header`          | Row number(s) to use as the column names    |
# | `names`           | Custom column names (overrides header)      |
# | `index_col`       | Set column(s) to be used as index          |
# | `usecols`         | Load selected columns                       |
# | `nrows`           | Limit the number of rows to read           |
# | `encoding`        | Handle text encodings like `UTF-8`, `ISO-8859-1`, etc. |

# %%
print("Orifinal_Data:\n",df_SalesData.head())
# Out:
# Orifinal_Data:
#           Date     Product  Units  UnitPrice  Revenue
# 0  2024-01-01     Monitor     46       1999    91954
# 1  2024-01-02    Keyboard      8       9999    79992
# 2  2024-01-03  Headphones     25        999    24975
# 3  2024-01-04     Monitor     35      14999   524965
# 4  2024-01-05  Headphones     25       2999    74975

# %%
# Step 1: Defining the file path
# The path to the CSV file is defined as a raw string (r) to handle any backslashes in the file path correctly.
sales_data_path = r"C:\Users\dhira\Desktop\GEN_AI_PROJECT\pandas\01_Foundation\dataset\raw\sample_sales.csv"

# Step 2: Reading the CSV file with specific columns
# pd.read_csv() is used to read the data from the CSV file.
# The 'usecols' parameter specifies which columns to read from the CSV file.
# In this case, only the 'Product', 'Units', and 'Revenue' columns will be loaded into the DataFrame.
df_SalesData = pd.read_csv(sales_data_path, usecols=['Product', 'Units', 'Revenue'])

# Step 3: Displaying the first few rows of the DataFrame
# .head() returns the first 5 rows of the DataFrame, which is useful for verifying that the correct data has been loaded.
df_SalesData.head()
# Out:
#       Product  Units  Revenue
# 0     Monitor     46    91954
# 1    Keyboard      8    79992
# 2  Headphones     25    24975
# 3     Monitor     35   524965
# 4  Headphones     25    74975

# %% [markdown]
# **Handling Missing or Bad Data**

# %%
df = pd.read_csv(sales_data_path,na_values=['?','NA','Missing'])
df
# Out:
#            Date     Product  Units  UnitPrice  Revenue
# 0    2024-01-01     Monitor     46       1999    91954
# 1    2024-01-02    Keyboard      8       9999    79992
# 2    2024-01-03  Headphones     25        999    24975
# 3    2024-01-04     Monitor     35      14999   524965
# 4    2024-01-05  Headphones     25       2999    74975
# ..          ...         ...    ...        ...      ...
# 115  2024-04-25  Headphones     26       4999   129974
# 116  2024-04-26    Keyboard     42      14999   629958
# 117  2024-04-27      Laptop     22        999    21978
# 118  2024-04-28     Monitor     14       1999    27986
# 119  2024-04-29       Mouse      2       2999     5998
#
# [120 rows x 5 columns]

# %% [markdown]
# **Large File Optimization**

# %%
import pandas as pd

# Define the path to the Superstore Sales dataset using a raw string
superstore_sales = r"C:\Users\dhira\Desktop\GEN_AI_PROJECT\pandas\01_Foundation\dataset\raw\superstore_sales.csv.csv"

# Try to read the CSV file in chunks, with error handling for possible issues
try:
    # Read the CSV file in chunks of 100 rows at a time using a different encoding (ISO-8859-1)
    # The 'ISO-8859-1' encoding is often used for files containing special characters in European languages.
    df_superstore = pd.read_csv(superstore_sales, encoding="ISO-8859-1", chunksize=100)

    # Iterate through each chunk of 100 rows and print the first 5 rows
    for data in df_superstore:
        print(data.head())  # Using .head() to display just the first 5 rows of each chunk

except FileNotFoundError:
    # If the file is not found, this block will catch it and print a custom error message
    print(f"The file at {superstore_sales} does not exist. Please check the file path.")

except Exception as e:
    # Catch any other unexpected errors and print them
    print(f"An error occurred: {e}")
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]
#      Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 100     101  CA-2016-158568   8/29/2016    9/2/2016  Standard Class
# 101     102  CA-2016-158568   8/29/2016    9/2/2016  Standard Class
# 102     103  CA-2016-129903   12/1/2016   12/4/2016    Second Class
# 103     104  US-2015-156867  11/13/2015  11/17/2015  Standard Class
# 104     105  US-2015-156867  11/13/2015  11/17/2015  Standard Class
#
#     Customer ID  Customer Name      Segment        Country       City  ...  \
# 100    RB-19465   Rick Bensley  Home Office  United States    Chicago  ...
# 101    RB-19465   Rick Bensley  Home Office  United States    Chicago  ...
# 102    GZ-14470  Gary Zandusky     Consumer  United States  Rochester  ...
# 103    LC-16870  Lena Cacioppo     Consumer  United States     Aurora  ...
# 104    LC-16870  Lena Cacioppo     Consumer  United States     Aurora  ...
#
#     Postal Code   Region       Product ID         Category Sub-Category  \
# 100       60610  Central  TEC-AC-10001767       Technology  Accessories
# 101       60610  Central  OFF-BI-10002609  Office Supplies      Binders
# 102       55901  Central  OFF-PA-10004040  Office Supplies        Paper
# 103       80013     West  TEC-AC-10001552       Technology  Accessories
# 104       80013     West  FUR-FU-10004006        Furniture  Furnishings
#
#                                           Product Name    Sales  Quantity  \
# 100  SanDisk Ultra 64 GB MicroSDHC Class 10 Memory ...   95.976         3
# 101      Avery Hidden Tab Dividers for Binding Systems    1.788         3
# 102  Universal Premium White Copier/Laser Paper (20...   23.920         4
# 103             Logitech K350 2.4Ghz Wireless Keyboard  238.896         6
# 104  Deflect-o DuraMat Lighweight, Studded, Beveled...  102.360         3
#
#      Discount   Profit
# 100       0.2 -10.7973
# 101       0.8  -3.0396
# 102       0.0  11.7208
# 103       0.2 -26.8758
# 104       0.2  -3.8385
#
# [5 rows x 21 columns]
#      Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 200     201  CA-2017-105074   6/24/2017   6/29/2017  Standard Class
# 201     202  CA-2014-133690    8/3/2014    8/5/2014     First Class
# 202     203  CA-2014-133690    8/3/2014    8/5/2014     First Class
# 203     204  US-2017-116701  12/17/2017  12/21/2017    Second Class
# 204     205  CA-2017-126382    6/3/2017    6/7/2017  Standard Class
#
#     Customer ID     Customer Name    Segment        Country      City  ...  \
# 200    MB-17305   Maria Bertelson   Consumer  United States     Akron  ...
# 201    BS-11755     Bruce Stewart   Consumer  United States    Denver  ...
# 202    BS-11755     Bruce Stewart   Consumer  United States    Denver  ...
# 203    LC-17140      Logan Currie   Consumer  United States    Dallas  ...
# 204    HK-14890  Heather Kirkland  Corporate  United States  Franklin  ...
#
#     Postal Code   Region       Product ID         Category Sub-Category  \
# 200       44312     East  OFF-PA-10002666  Office Supplies        Paper
# 201       80219     West  FUR-TA-10004289        Furniture       Tables
# 202       80219     West  OFF-AP-10003622  Office Supplies   Appliances
# 203       75220  Central  OFF-AP-10003217  Office Supplies   Appliances
# 204       37064    South  FUR-FU-10002960        Furniture  Furnishings
#
#                                           Product Name    Sales  Quantity  \
# 200  Southworth 25% Cotton Linen-Finish Paper & Env...   21.744         3
# 201  BoxOffice By Design Rectangular and Half-Moon ...  218.750         2
# 202  Bravo II Megaboss 12-Amp Hard Body Upright, Re...    2.600         1
# 203               Eureka Sanitaire  Commercial Upright   66.284         2
# 204         Eldon 200 Class Desk Accessories, Burgundy   35.168         7
#
#      Discount    Profit
# 200       0.2    6.7950
# 201       0.5 -161.8750
# 202       0.2    0.2925
# 203       0.8 -178.9668
# 204       0.2    9.6712
#
# [5 rows x 21 columns]
#      Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 300     301  CA-2016-142545  10/28/2016   11/3/2016  Standard Class
# 301     302  CA-2016-142545  10/28/2016   11/3/2016  Standard Class
# 302     303  CA-2016-142545  10/28/2016   11/3/2016  Standard Class
# 303     304  US-2017-152380  11/19/2017  11/23/2017  Standard Class
# 304     305  CA-2015-144253    5/4/2015    5/9/2015    Second Class
#
#     Customer ID      Customer Name    Segment        Country           City  \
# 300    JD-15895   Jonathan Doherty  Corporate  United States     Belleville
# 301    JD-15895   Jonathan Doherty  Corporate  United States     Belleville
# 302    JD-15895   Jonathan Doherty  Corporate  United States     Belleville
# 303    JH-15910    Jonathan Howell   Consumer  United States        Chicago
# 304    AS-10225  Alan Schoenberger  Corporate  United States  New York City
#
#      ... Postal Code   Region       Product ID         Category Sub-Category  \
# 300  ...        7109     East  OFF-PA-10004243  Office Supplies        Paper
# 301  ...        7109     East  FUR-FU-10001861        Furniture  Furnishings
# 302  ...        7109     East  OFF-BI-10002706  Office Supplies      Binders
# 303  ...       60623  Central  FUR-TA-10002533        Furniture       Tables
# 304  ...       10024     East  FUR-FU-10002671        Furniture  Furnishings
#
#                                           Product Name    Sales  Quantity  \
# 300                                         Xerox 1939   56.910         3
# 301  Floodlight Indoor Halogen Bulbs, 1 Bulb per Pa...   77.600         4
# 302  Avery Premier Heavy-Duty Binder with Round Loc...   14.280         1
# 303                              BPI Conference Tables  219.075         3
# 304  Electrix 20W Halogen Replacement Bulb for Zoom...   26.800         2
#
#      Discount    Profit
# 300       0.0   27.3168
# 301       0.0   38.0240
# 302       0.0    6.5688
# 303       0.5 -131.4450
# 304       0.0   12.8640
#
# [5 rows x 21 columns]
#      Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 400     401  CA-2016-108987    9/8/2016   9/10/2016    Second Class
# 401     402  CA-2016-108987    9/8/2016   9/10/2016    Second Class
# 402     403  CA-2014-113166  12/24/2014  12/26/2014     First Class
# 403     404  CA-2014-155208   4/16/2014   4/20/2014  Standard Class
# 404     405  CA-2017-117933  12/24/2017  12/29/2017  Standard Class
#
#     Customer ID     Customer Name    Segment        Country           City  \
# 400    AG-10675       Anna Gayman   Consumer  United States        Houston
# 401    AG-10675       Anna Gayman   Consumer  United States        Houston
# 402    LF-17185       Luke Foster   Consumer  United States          Miami
# 403    SP-20650  Stephanie Phelps  Corporate  United States     Wilmington
# 404    RF-19840   Roy Französisch   Consumer  United States  New York City
#
#      ... Postal Code   Region       Product ID         Category Sub-Category  \
# 400  ...       77036  Central  OFF-ST-10000934  Office Supplies      Storage
# 401  ...       77036  Central  TEC-AC-10000158       Technology  Accessories
# 402  ...       33180    South  OFF-PA-10001947  Office Supplies        Paper
# 403  ...       28403    South  OFF-AR-10003478  Office Supplies          Art
# 404  ...       10024     East  OFF-AP-10004249  Office Supplies   Appliances
#
#                                           Product Name    Sales  Quantity  \
# 400             Contico 72"H Heavy-Duty Storage System  131.136         4
# 401      Sony 64GB Class 10 Micro SDHC R40 Memory Card   57.584         2
# 402                                         Xerox 1974    9.568         2
# 403  Avery Hi-Liter EverBold Pen Style Fluorescent ...   39.072         6
# 404                                      Staple holder   35.910         3
#
#      Discount   Profit
# 400       0.2 -32.7840
# 401       0.2   0.7198
# 402       0.2   3.4684
# 403       0.2   9.7680
# 404       0.0   9.6957
#
# [5 rows x 21 columns]
#      Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 500     501  US-2016-105578  5/30/2016  6/4/2016  Standard Class    MY-17380
# 501     502  US-2016-105578  5/30/2016  6/4/2016  Standard Class    MY-17380
# 502     503  US-2016-105578  5/30/2016  6/4/2016  Standard Class    MY-17380
# 503     504  US-2016-105578  5/30/2016  6/4/2016  Standard Class    MY-17380
# 504     505  US-2016-105578  5/30/2016  6/4/2016  Standard Class    MY-17380
#
#        Customer Name    Segment        Country    City  ... Postal Code  \
# 500  Maribeth Yedwab  Corporate  United States  Parker  ...       80134
# 501  Maribeth Yedwab  Corporate  United States  Parker  ...       80134
# 502  Maribeth Yedwab  Corporate  United States  Parker  ...       80134
# 503  Maribeth Yedwab  Corporate  United States  Parker  ...       80134
# 504  Maribeth Yedwab  Corporate  United States  Parker  ...       80134
#
#      Region       Product ID         Category Sub-Category  \
# 500    West  OFF-BI-10001670  Office Supplies      Binders
# 501    West  OFF-BI-10001658  Office Supplies      Binders
# 502    West  FUR-CH-10001215        Furniture       Chairs
# 503    West  OFF-BI-10000831  Office Supplies      Binders
# 504    West  OFF-PA-10000357  Office Supplies        Paper
#
#                                           Product Name    Sales  Quantity  \
# 500                       Vinyl Sectional Post Binders   22.620         2
# 501                   GBC Standard Therm-A-Bind Covers   14.952         2
# 502      Global Troy Executive Leather Low-Back Tilter  801.568         2
# 503   Storex Flexible Poly Binders with Double Pockets    2.376         3
# 504  White Dual Perf Computer Printout Paper, 2700 ...   32.792         1
#
#      Discount   Profit
# 500       0.7 -15.0800
# 501       0.7 -11.9616
# 502       0.2  50.0980
# 503       0.7  -1.9008
# 504       0.2  11.8871
#
# [5 rows x 21 columns]
#      Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 600     601  US-2016-100720  7/16/2016  7/21/2016  Standard Class    CK-12205
# 601     602  US-2016-100720  7/16/2016  7/21/2016  Standard Class    CK-12205
# 602     603  CA-2014-149958  3/15/2014  3/19/2014  Standard Class    AS-10240
# 603     604  CA-2014-149958  3/15/2014  3/19/2014  Standard Class    AS-10240
# 604     605  CA-2014-149958  3/15/2014  3/19/2014  Standard Class    AS-10240
#
#            Customer Name   Segment        Country          City  ...  \
# 600  Chloris Kastensmidt  Consumer  United States  Philadelphia  ...
# 601  Chloris Kastensmidt  Consumer  United States  Philadelphia  ...
# 602         Alan Shonely  Consumer  United States         Tampa  ...
# 603         Alan Shonely  Consumer  United States         Tampa  ...
# 604         Alan Shonely  Consumer  United States         Tampa  ...
#
#     Postal Code  Region       Product ID         Category Sub-Category  \
# 600       19120    East  TEC-PH-10003963       Technology       Phones
# 601       19120    East  OFF-SU-10001574  Office Supplies     Supplies
# 602       33614   South  OFF-ST-10001490  Office Supplies      Storage
# 603       33614   South  FUR-FU-10001756        Furniture  Furnishings
# 604       33614   South  OFF-BI-10000773  Office Supplies      Binders
#
#                                           Product Name    Sales  Quantity  \
# 600                      GE 2-Jack Phone Line Splitter  494.376         4
# 601                           Acme Value Line Scissors    5.840         2
# 602                     Hot File 7-Pocket, Floor Stand  142.776         1
# 603  Eldon Expressions Desk Accessory, Wood Photo F...   45.696         3
# 604                Insertable Tab Post Binder Dividers    7.218         3
#
#      Discount    Profit
# 600       0.4 -115.3544
# 601       0.2    0.7300
# 602       0.2   17.8470
# 603       0.2    5.1408
# 604       0.7   -5.5338
#
# [5 rows x 21 columns]
#      Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 700     701  CA-2015-119291  5/14/2015  5/17/2015     First Class    JO-15550
# 701     702  CA-2017-114552   9/2/2017   9/8/2017  Standard Class    Dl-13600
# 702     703  CA-2016-163755  11/4/2016  11/8/2016    Second Class    AS-10285
# 703     704  CA-2015-142027   4/9/2015  4/14/2015  Standard Class    JK-15370
# 704     705  CA-2014-138527  9/12/2014  9/17/2014  Standard Class    BN-11470
#
#         Customer Name      Segment        Country        City  ...  \
# 700      Jesus Ocampo  Home Office  United States     Chester  ...
# 701      Dorris liebe    Corporate  United States   Cleveland  ...
# 702  Alejandro Savely    Corporate  United States     Seattle  ...
# 703        Jay Kimmel     Consumer  United States  Long Beach  ...
# 704      Brad Norvell    Corporate  United States        Cary  ...
#
#     Postal Code  Region       Product ID         Category Sub-Category  \
# 700       19013    East  OFF-BI-10001982  Office Supplies      Binders
# 701       44105    East  FUR-FU-10002960        Furniture  Furnishings
# 702       98103    West  FUR-FU-10003394        Furniture  Furnishings
# 703       90805    West  FUR-TA-10002774        Furniture       Tables
# 704       27511   South  OFF-PA-10001800  Office Supplies        Paper
#
#                                    Product Name    Sales  Quantity  Discount  \
# 700  Wilson Jones Custom Binder Spines & Labels    4.896         3       0.7
# 701  Eldon 200 Class Desk Accessories, Burgundy   15.072         3       0.2
# 702      Tenex "The Solids" Textured Chair Mats  209.880         3       0.0
# 703                  Laminate Occasional Tables  369.912         3       0.2
# 704                                   Xerox 220   10.368         2       0.2
#
#       Profit
# 700  -3.4272
# 701   4.1448
# 702  35.6796
# 703 -13.8717
# 704   3.6288
#
# [5 rows x 21 columns]
#      Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 800     801  CA-2017-105809  2/20/2017  2/23/2017     First Class    HW-14935
# 801     802  CA-2017-105809  2/20/2017  2/23/2017     First Class    HW-14935
# 802     803  CA-2016-136133  8/18/2016  8/23/2016    Second Class    HW-14935
# 803     804  CA-2016-115504  3/12/2016  3/17/2016  Standard Class    MC-18130
# 804     805  CA-2017-135783  4/22/2017  4/24/2017     First Class    GM-14440
#
#        Customer Name    Segment        Country           City  ...  \
# 800  Helen Wasserman  Corporate  United States      San Diego  ...
# 801  Helen Wasserman  Corporate  United States      San Diego  ...
# 802  Helen Wasserman  Corporate  United States  New York City  ...
# 803      Mike Caudle  Corporate  United States         Monroe  ...
# 804      Gary McGarr   Consumer  United States  San Francisco  ...
#
#     Postal Code  Region       Product ID         Category Sub-Category  \
# 800       92105    West  FUR-FU-10004090        Furniture  Furnishings
# 801       92105    West  TEC-PH-10001580       Technology       Phones
# 802       10024    East  OFF-AP-10000576  Office Supplies   Appliances
# 803       71203   South  OFF-PA-10003953  Office Supplies        Paper
# 804       94122    West  FUR-FU-10000794        Furniture  Furnishings
#
#                                           Product Name    Sales  Quantity  \
# 800      Executive Impressions 14" Contract Wall Clock   22.230         1
# 801  Logitech Mobile Speakerphone P710e - speaker p...  215.968         2
# 802                     Belkin 7 Outlet SurgeMaster II  355.320         9
# 803                                          Xerox 218   12.960         2
# 804      Eldon Stackable Tray, Side-Load, Legal, Smoke   18.280         2
#
#      Discount   Profit
# 800       0.0   7.3359
# 801       0.2  18.8972
# 802       0.0  99.4896
# 803       0.0   6.2208
# 804       0.0   6.2152
#
# [5 rows x 21 columns]
#      Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 900     901  CA-2017-150959  11/11/2017  11/13/2017     First Class
# 901     902  CA-2017-150959  11/11/2017  11/13/2017     First Class
# 902     903  CA-2017-132353   9/15/2017   9/17/2017     First Class
# 903     904  CA-2016-130477    4/8/2016   4/12/2016  Standard Class
# 904     905  CA-2016-130477    4/8/2016   4/12/2016  Standard Class
#
#     Customer ID  Customer Name   Segment        Country         City  ...  \
# 900    TD-20995  Tamara Dahlen  Consumer  United States      Garland  ...
# 901    TD-20995  Tamara Dahlen  Consumer  United States      Garland  ...
# 902    DB-13060    Dave Brooks  Consumer  United States      Chicago  ...
# 903    LC-17140   Logan Currie  Consumer  United States  Los Angeles  ...
# 904    LC-17140   Logan Currie  Consumer  United States  Los Angeles  ...
#
#     Postal Code   Region       Product ID         Category Sub-Category  \
# 900       75043  Central  OFF-LA-10001045  Office Supplies       Labels
# 901       75043  Central  OFF-BI-10001510  Office Supplies      Binders
# 902       60653  Central  TEC-PH-10004536       Technology       Phones
# 903       90032     West  OFF-PA-10002947  Office Supplies        Paper
# 904       90032     West  OFF-ST-10002583  Office Supplies      Storage
#
#                                           Product Name    Sales  Quantity  \
# 900  Permanent Self-Adhesive File Folder Labels for...   10.440         5
# 901          Deluxe Heavy-Duty Vinyl Round Ring Binder   18.336         4
# 902                           Avaya 5420 Digital phone  323.976         3
# 903                                         Xerox 1923   20.040         3
# 904                  Fellowes Neat Ideas Storage Cubes   64.960         2
#
#      Discount   Profit
# 900       0.2   3.3930
# 901       0.8 -32.0880
# 902       0.2  20.2485
# 903       0.0   9.6192
# 904       0.0   2.5984
#
# [5 rows x 21 columns]
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 1000    1001  CA-2016-155488  11/13/2016  11/17/2016  Standard Class
# 1001    1002  CA-2015-124891   7/31/2015   7/31/2015        Same Day
# 1002    1003  CA-2015-124891   7/31/2015   7/31/2015        Same Day
# 1003    1004  CA-2015-124891   7/31/2015   7/31/2015        Same Day
# 1004    1005  CA-2015-126445   8/27/2015   8/31/2015  Standard Class
#
#      Customer ID Customer Name      Segment        Country           City  \
# 1000    FM-14290  Frank Merwin  Home Office  United States      Vancouver
# 1001    RH-19495   Rick Hansen     Consumer  United States  New York City
# 1002    RH-19495   Rick Hansen     Consumer  United States  New York City
# 1003    RH-19495   Rick Hansen     Consumer  United States  New York City
# 1004    RA-19945     Ryan Akin     Consumer  United States       Murrieta
#
#       ... Postal Code  Region       Product ID         Category Sub-Category  \
# 1000  ...       98661    West  OFF-AR-10002956  Office Supplies          Art
# 1001  ...       10024    East  TEC-AC-10003033       Technology  Accessories
# 1002  ...       10024    East  FUR-TA-10002903        Furniture       Tables
# 1003  ...       10024    East  OFF-PA-10004621  Office Supplies        Paper
# 1004  ...       92563    West  OFF-ST-10000046  Office Supplies      Storage
#
#                                            Product Name     Sales  Quantity  \
# 1000     Boston 16801 Nautilus Battery Pencil Sharpener    44.020         2
# 1001  Plantronics CS510 - Over-the-Head monaural Wir...  2309.650         7
# 1002            Bevis Round Bullnose 29" High Table Top  1090.782         7
# 1003                                          Xerox 212    19.440         3
# 1004                   Fellowes Super Stor/Drawer Files   484.650         3
#
#       Discount    Profit
# 1000       0.0   11.4452
# 1001       0.0  762.1845
# 1002       0.4 -290.8752
# 1003       0.0    9.3312
# 1004       0.0   92.0835
#
# [5 rows x 21 columns]
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 1100    1101  CA-2016-107216   6/14/2016   6/17/2016     First Class
# 1101    1102  CA-2016-107216   6/14/2016   6/17/2016     First Class
# 1102    1103  US-2017-145863   4/21/2017   4/27/2017  Standard Class
# 1103    1104  US-2017-145863   4/21/2017   4/27/2017  Standard Class
# 1104    1105  CA-2016-112340  10/21/2016  10/27/2016  Standard Class
#
#      Customer ID  Customer Name      Segment        Country           City  \
# 1100    PV-18985  Paul Van Hugh  Home Office  United States  San Francisco
# 1101    PV-18985  Paul Van Hugh  Home Office  United States  San Francisco
# 1102    RP-19390   Resi Pölking     Consumer  United States        Houston
# 1103    RP-19390   Resi Pölking     Consumer  United States        Houston
# 1104    NM-18520   Neoma Murray     Consumer  United States      Riverside
#
#       ... Postal Code   Region       Product ID         Category Sub-Category  \
#
#
# [5 rows x 21 columns]
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2300    2301  CA-2014-162362  11/14/2014  11/18/2014  Standard Class
# 2301    2302  CA-2014-162362  11/14/2014  11/18/2014  Standard Class
# 2302    2303  CA-2016-106558   1/17/2016   1/21/2016  Standard Class
# 2303    2304  CA-2017-157931   9/17/2017   9/22/2017    Second Class
# 2304    2305  CA-2017-157931   9/17/2017   9/22/2017    Second Class
#
#      Customer ID    Customer Name      Segment        Country      City  ...  \
# 2300    JL-15505  Jeremy Lonsdale     Consumer  United States   Midland  ...
# 2301    JL-15505  Jeremy Lonsdale     Consumer  United States   Midland  ...
# 2302    DL-13495     Dionis Lloyd    Corporate  United States  Columbus  ...
# 2303    MO-17800     Meg O'Connel  Home Office  United States   Roswell  ...
# 2304    MO-17800     Meg O'Connel  Home Office  United States   Roswell  ...
#
#      Postal Code   Region       Product ID         Category Sub-Category  \
# 2300       48640  Central  OFF-BI-10000756  Office Supplies      Binders
# 2301       48640  Central  OFF-BI-10000546  Office Supplies      Binders
# 2302       31907    South  TEC-AC-10001142       Technology  Accessories
# 2303       30076    South  FUR-CH-10000785        Furniture       Chairs
# 2304       30076    South  OFF-PA-10000474  Office Supplies        Paper
#
#                                           Product Name   Sales  Quantity  \
# 2300  Storex DuraTech Recycled Plastic Frosted Binders   12.72         3
# 2301                             Avery Durable Binders   11.52         4
# 2302                           First Data FD10 PIN Pad  316.00         4
# 2303                   Global Ergonomic Managers Chair  723.92         4
# ...
# 9101       0.2    5.3190
# 9102       0.2  -16.9568
# 9103       0.6  -84.4480
# 9104       0.8  -51.2960
#
# [5 rows x 21 columns]
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 9200    9201  CA-2016-152688  10/17/2016  10/20/2016     First Class
# 9201    9202  CA-2016-152688  10/17/2016  10/20/2016     First Class
# 9202    9203  CA-2016-153836  10/30/2016   11/3/2016  Standard Class
# 9203    9204  CA-2016-153836  10/30/2016   11/3/2016  Standard Class
# 9204    9205  CA-2016-104689   12/1/2016   12/5/2016  Standard Class
#
#      Customer ID Customer Name    Segment        Country           City  ...  \
# 9200    NR-18550  Nick Radford   Consumer  United States    Perth Amboy  ...
# 9201    NR-18550  Nick Radford   Consumer  United States    Perth Amboy  ...
# 9202    EH-13765  Edward Hooks  Corporate  United States  New York City  ...
# 9203    EH-13765  Edward Hooks  Corporate  United States  New York City  ...
# 9204    FH-14365  Fred Hopkins  Corporate  United States    Los Angeles  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# 9200        8861    East  FUR-BO-10001337        Furniture    Bookcases
# 9201        8861    East  OFF-BI-10004584  Office Supplies      Binders
# 9202       10011    East  OFF-BI-10004817  Office Supplies      Binders
# 9203       10011    East  OFF-AR-10004602  Office Supplies          Art
# 9204       90004    West  OFF-AR-10001149  Office Supplies          Art
#
#                                         Product Name    Sales  Quantity  \
# 9200  O'Sullivan Living Dimensions 2-Shelf Bookcases  120.980         1
# 9201    GBC ProClick 150 Presentation Binding System  315.980         1
# 9202                    GBC Personal VeloBind Strips   28.752         3
# 9203    Boston KS Multi-Size Manual Pencil Sharpener  114.950         5
# 9204       Sanford Colorific Colored Pencils, 12/Box   23.040         8
#
#       Discount    Profit
# 9200       0.0   12.0980
# 9201       0.0  148.5106
# 9202       0.2   10.0632
# 9203       0.0   32.1860
# 9204       0.0    6.9120
#
# [5 rows x 21 columns]
#       Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 9300    9301  US-2015-163433  4/18/2015  4/22/2015  Second Class    MP-17965
# 9301    9302  US-2015-163433  4/18/2015  4/22/2015  Second Class    MP-17965
# 9302    9303  US-2015-163433  4/18/2015  4/22/2015  Second Class    MP-17965
# 9303    9304  US-2015-163433  4/18/2015  4/22/2015  Second Class    MP-17965
# 9304    9305  US-2015-163433  4/18/2015  4/22/2015  Second Class    MP-17965
#
#       Customer Name    Segment        Country     City  ... Postal Code  \
# 9300  Michael Paige  Corporate  United States  Mcallen  ...       78501
# 9301  Michael Paige  Corporate  United States  Mcallen  ...       78501
# 9302  Michael Paige  Corporate  United States  Mcallen  ...       78501
# 9303  Michael Paige  Corporate  United States  Mcallen  ...       78501
# 9304  Michael Paige  Corporate  United States  Mcallen  ...       78501
#
#        Region       Product ID         Category Sub-Category  \
# 9300  Central  FUR-CH-10000225        Furniture       Chairs
# 9301  Central  TEC-PH-10001870       Technology       Phones
# 9302  Central  OFF-AR-10003481  Office Supplies          Art
# 9303  Central  OFF-PA-10003936  Office Supplies        Paper
# 9304  Central  OFF-BI-10000320  Office Supplies      Binders
#
#                                            Product Name   Sales  Quantity  \
# 9300                 Global Geo Office Task Chair, Gray  56.686         1
# 9301  Lunatik TT5L-002 Taktik Strike Impact Protecti...  97.968         2
# 9302                                         Newell 348   7.872         3
# 9303                                         Xerox 1994  15.552         3
# 9304                          GBC Plastic Binding Combs   1.476         1
#
#       Discount   Profit
# 9300       0.3 -20.2450
# 9301       0.2   6.1230
# 9302       0.2   0.8856
# 9303       0.2   5.4432
# 9304       0.8  -2.2878
#
# [5 rows x 21 columns]
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9400    9401  CA-2015-167696  9/16/2015  9/21/2015  Standard Class
# 9401    9402  CA-2014-159814  6/24/2014  6/28/2014  Standard Class
# 9402    9403  CA-2016-105459  8/12/2016  8/17/2016    Second Class
# 9403    9404  CA-2016-105459  8/12/2016  8/17/2016    Second Class
# 9404    9405  CA-2017-141663  4/13/2017  4/17/2017  Standard Class
#
#      Customer ID    Customer Name    Segment        Country           City  \
# 9400    BD-11500  Bradley Drucker   Consumer  United States   Newport News
# 9401    LP-17080    Liz Pelletier   Consumer  United States         Tucson
# 9402    NP-18700       Nora Preis   Consumer  United States  New York City
# 9403    NP-18700       Nora Preis   Consumer  United States  New York City
# 9404    DP-13105     Dave Poirier  Corporate  United States   Philadelphia
#
#       ... Postal Code  Region       Product ID         Category Sub-Category  \
# 9400  ...       23602   South  OFF-EN-10001539  Office Supplies    Envelopes
# 9401  ...       85705    West  FUR-FU-10001731        Furniture  Furnishings
# 9402  ...       10024    East  FUR-TA-10001095        Furniture       Tables
# 9403  ...       10024    East  OFF-ST-10000078  Office Supplies      Storage
# 9404  ...       19134    East  OFF-FA-10004076  Office Supplies    Fasteners
#
#                                Product Name     Sales  Quantity  Discount  \
# 9400                        Staple envelope    31.120         4       0.0
# 9401      Acrylic Self-Standing Desk Frames     4.272         2       0.2
# 9402     Chromcraft Round Conference Tables   209.148         2       0.4
# 9403  Tennsco 6- and 18-Compartment Lockers  1591.020         6       0.0
# 9404           Translucent Push Pins by OIC     7.920         5       0.2
#
#         Profit
# 9400   14.6264
# 9401    0.9612
# 9402  -66.2302
# 9403  286.3836
# 9404    1.6830
#
# [5 rows x 21 columns]
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 
#
# [5 rows x 21 columns]
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 9700    9701  CA-2017-154116  12/15/2017  12/19/2017  Standard Class
# 9701    9702  CA-2016-105291  10/30/2016   11/4/2016  Standard Class
# 9702    9703  CA-2017-147032   7/31/2017    8/4/2017  Standard Class
# 9703    9704  CA-2017-147032   7/31/2017    8/4/2017  Standard Class
# 9704    9705  CA-2017-147032   7/31/2017    8/4/2017  Standard Class
#
#      Customer ID   Customer Name      Segment        Country             City  \
# 9700    KM-16660    Khloe Miller     Consumer  United States        Inglewood
# 9701    SP-20920    Susan Pistek     Consumer  United States  San Luis Obispo
# 9702    LB-16795  Laurel Beltran  Home Office  United States       Wilmington
# 9703    LB-16795  Laurel Beltran  Home Office  United States       Wilmington
# 9704    LB-16795  Laurel Beltran  Home Office  United States       Wilmington
#
#       ... Postal Code  Region       Product ID         Category Sub-Category  \
# 9700  ...       90301    West  TEC-PH-10000675       Technology       Phones
# 9701  ...       93405    West  OFF-FA-10003059  Office Supplies    Fasteners
# 9702  ...       19805    East  OFF-PA-10003256  Office Supplies        Paper
# 9703  ...       19805    East  OFF-BI-10003656  Office Supplies      Binders
# 9704  ...       19805    East  OFF-BI-10002897  Office Supplies      Binders
#
#                                            Product Name    Sales  Quantity  \
# 9700                  Panasonic KX TS3282B Corded phone  196.776         3
# 9701                           Assorted Color Push Pins    3.620         2
# 9702         Avery Personal Creations Heavyweight Cards   11.540         1
# 9703        Fellowes PB200 Plastic Comb Binding Machine  849.950         5
# 9704  Black Avery Memo-Size 3-Ring Binder, 5 1/2" x ...   11.010         3
#
#       Discount    Profit
# 9700       0.2   14.7582
# 9701       0.0    1.1946
# 9702       0.0    5.5392
# 9703       0.0  390.9770
# 9704       0.0    5.3949
#
# [5 rows x 21 columns]
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9800    9801  CA-2015-128608  1/12/2015  1/17/2015  Standard Class
# 9801    9802  CA-2017-137918  9/29/2017  10/6/2017  Standard Class
# 9802    9803  CA-2015-122973  7/18/2015  7/20/2015    Second Class
# 9803    9804  CA-2015-122973  7/18/2015  7/20/2015    Second Class
# 9804    9805  CA-2015-122973  7/18/2015  7/20/2015    Second Class
#
#      Customer ID     Customer Name    Segment        Country           City  \
# 9800    CS-12490  Cindy Schnelling  Corporate  United States         Toledo
# 9801    JK-15730     Joe Kamberova   Consumer  United States           Lodi
# 9802    PJ-19015   Pauline Johnson   Consumer  United States  New York City
# 9803    PJ-19015   Pauline Johnson   Consumer  United States  New York City
# 9804    PJ-19015   Pauline Johnson   Consumer  United States  New York City
#
#       ... Postal Code  Region       Product ID         Category Sub-Category  \
# 9800  ...       43615    East  TEC-PH-10002262       Technology       Phones
# 9801  ...       95240    West  OFF-SU-10000898  Office Supplies     Supplies
# 9802  ...       10024    East  OFF-BI-10004182  Office Supplies      Binders
# 9803  ...       10024    East  TEC-PH-10002468       Technology       Phones
# 9804  ...       10024    East  FUR-FU-10002364        Furniture  Furnishings
#
#                                            Product Name    Sales  Quantity  \
# 9800     LG Electronics Tone+ HBS-730 Bluetooth Headset  107.118         3
# 9801  Acme Hot Forged Carbon Steel Scissors with Nic...   97.300         7
# 9802                                    Economy Binders    3.328         2
# 9803  Plantronics CS 50-USB - headset - Convertible,...  135.990         1
# 9804       Eldon Expressions Wood Desk Accessories, Oak    7.380         1
#
#       Discount   Profit
# 9800       0.4 -21.4236
# 9801       0.0  28.2170
# 9802       0.2   1.2064
# 9803       0.0  36.7173
# 9804       0.0   2.1402
#
# [5 rows x 21 columns]
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 9900    9901  CA-2017-117646   8/21/2017   8/25/2017  Standard Class
# 9901    9902  CA-2017-117646   8/21/2017   8/25/2017  Standard Class
# 9902    9903  CA-2017-117646   8/21/2017   8/25/2017  Standard Class
# 9903    9904  CA-2014-122609  11/12/2014  11/18/2014  Standard Class
# 9904    9905  CA-2014-122609  11/12/2014  11/18/2014  Standard Class
#
#      Customer ID  Customer Name   Segment        Country        City  ...  \
# 9900    SC-20845     Sung Chung  Consumer  United States  Louisville  ...
# 9901    SC-20845     Sung Chung  Consumer  United States  Louisville  ...
# 9902    SC-20845     Sung Chung  Consumer  United States  Louisville  ...
# 9903    DP-13000  Darren Powers  Consumer  United States  Carrollton  ...
# 9904    DP-13000  Darren Powers  Consumer  United States  Carrollton  ...
#
#      Postal Code   Region       Product ID         Category Sub-Category  \
# 9900       80027     West  OFF-ST-10000036  Office Supplies      Storage
# 9901       80027     West  FUR-FU-10001037        Furniture  Furnishings
# 9902       80027     West  OFF-PA-10001950  Office Supplies        Paper
# 9903       75007  Central  FUR-FU-10004587        Furniture  Furnishings
# 9904       75007  Central  TEC-AC-10002567       Technology  Accessories
#
#                                            Product Name    Sales  Quantity  \
# 9900  Recycled Data-Pak for Archival Bound Computer ...  237.096         3
# 9901     DAX Charcoal/Nickel-Tone Document Frame, 5 x 7   22.752         3
# 9902  Southworth 25% Cotton Antique Laid Paper & Env...    6.672         1
# 9903  GE General Use Halogen Bulbs, 100 Watts, 1 Bul...   25.128         3
# 9904                Logitech G602 Wireless Gaming Mouse  127.984         2
#
#       Discount   Profit
# 9900       0.2  20.7459
# 9901       0.2   7.1100
# 9902       0.2   2.0850
# 9903       0.6  -6.9102
# 9904       0.2  25.5968
#
# [5 rows x 21 columns]

# %% [markdown]
# **🧩 Reading Excel Files**

# %%
# Import pandas library (make sure you've imported it before running this code)
import pandas as pd

# Define the path to the Excel file containing the dataset.
# Update this path if the file is stored elsewhere on your system.
people_basic = r"C:\Users\dhira\Desktop\GEN_AI_PROJECT\pandas\01_Foundation\dataset\raw\people_basic_data.xlsx"

# Read the Excel file into a pandas DataFrame.
# pd.read_excel() automatically detects the sheet unless specified using 'sheet_name' parameter.
df_exl = pd.read_excel(people_basic)

# Display the first 5 rows of the DataFrame to get a quick overview of the data.
# This helps verify that the file was read correctly and understand the structure of the dataset.
print(df_exl.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# **🧩 Reading Excel Files (Sheets)**

# %%
# Import pandas library — required for data manipulation and reading Excel files
import pandas as pd

# Define the path to the Excel file.
# The 'r' before the string makes it a raw string, so backslashes are treated literally.
people_basic_sheet = r"C:\Users\dhira\Desktop\GEN_AI_PROJECT\pandas\01_Foundation\dataset\raw\people_basic_data.xlsx"

# Read a specific sheet ("peoplebasic") from the Excel file into a pandas DataFrame.
# The 'sheet_name' parameter specifies which sheet to load — useful when the file contains multiple sheets.
df_ex_sheet = pd.read_excel(people_basic_sheet, sheet_name="peoplebasic")

# Print the entire DataFrame to view its contents.
# Be careful: if the dataset is large, this will print all rows.
# You can use df_ex_sheet.head() instead to show only the first 5 rows.
print(df_ex_sheet.head())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[91], line 10
#       6 people_basic_sheet = r"C:\Users\dhira\Desktop\GEN_AI_PROJECT\pandas\01_Foundation\dataset\raw\people_basic_data.xlsx"
#       8 # Read a specific sheet ("peoplebasic") from the Excel file into a pandas DataFrame.
#       9 # The 'sheet_name' parameter specifies which sheet to load — useful when the file contains multiple sheets.
# ---> 10 df_ex_sheet = pd.read_excel(people_basic_sheet, sheet_name="peoplebasic")
#      12 # Print the entire DataFrame to view its contents.
#      13 # Be careful: if the dataset is large, this will print all rows.
#      14 # You can use df_ex_sheet.head() instead to show only the first 5 rows.
#      15 print(df_ex_sheet.head())
#
# File c:\Users\dhira\Desktop\GEN_AI_PROJECT\env\Lib\site-packages\pandas\io\excel\_base.py:508, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#     507 try:
# --> 508     data = io.parse(
#     509         sheet_name=sheet_name,
#     510         header=header,
#     511         names=names,
#     512         index_col=index_col,
#     513         usecols=usecols,
#     514         dtype=dtype,
#     515         converters=converters,
#     516         true_values=true_values,
#     517         false_values=false_values,
#     518         skiprows=skiprows,
#     519         nrows=nrows,
#     520         na_values=na_values,
#     521         keep_default_na=keep_default_na,
#     522         na_filter=na_filter,
#     523         verbose=verbose,
#     524         parse_dates=parse_dates,
#     525         date_parser=date_parser,
#     526         date_format=date_format,
#     527         thousands=thousands,
#     528         decimal=decimal,
#     529         comment=comment,
#     530         skipfooter=skipfooter,
#     531         dtype_backend=dtype_backend,
#     532     )
#     533 finally:
#     534     # make sure to close opened file handles
#     535     if should_close:
#
# File c:\Users\dhira\Desktop\GEN_AI_PROJECT\env\Lib\site-packages\pandas\io\excel\_base.py:1616, in ExcelFile.parse(self, sheet_name, header, names, index_col, usecols, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_parser, date_format, thousands, comment, skipfooter, dtype_backend, **kwds)
#    1576 def parse(
#    1577     self,
#    1578     sheet_name: str | int | list[int] | list[str] | None = 0,
#    (...)
#    1596     **kwds,
#    1597 ) -> DataFrame | dict[str, DataFrame] | dict[int, DataFrame]:
#    1598     """
#    1599     Parse specified sheet(s) into a DataFrame.
#    1600
#    (...)
#    1614     >>> file.parse()  # doctest: +SKIP
#    1615     """
# -> 1616     return self._reader.parse(
#    1617         sheet_name=sheet_name,
#    1618         header=header,
#    1619         names=names,
#    1620         index_col=index_col,
#    1621         usecols=usecols,
#    1622         converters=converters,
#    1623         true_values=true_values,
#    1624         false_values=false_values,
#    1625         skiprows=skiprows,
#    1626         nrows=nrows,
#    1627         na_values=na_values,
#    1628         parse_dates=parse_dates,
#    1629         date_parser=date_parser,
#    1630         date_format=date_format,
#    1631         thousands=thousands,
#    1632         comment=comment,
#    1633         skipfooter=skipfooter,
#    1634         dtype_backend=dtype_backend,
#    1635         **kwds,
#    1636     )
#
# File c:\Users\dhira\Desktop\GEN_AI_PROJECT\env\Lib\site-packages\pandas\io\excel\_base.py:773, in BaseExcelReader.parse(self, sheet_name, header, names, index_col, usecols, dtype, true_values, false_values, skiprows, nrows, na_values, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, dtype_backend, **kwds)
#     770     print(f"Reading sheet {asheetname}")
#     772 if isinstance(asheetname, str):
# --> 773     sheet = self.get_sheet_by_name(asheetname)
#     774 else:  # assume an integer if not a string
#     775     sheet = self.get_sheet_by_index(asheetname)
#
# File c:\Users\dhira\Desktop\GEN_AI_PROJECT\env\Lib\site-packages\pandas\io\excel\_openpyxl.py:582, in OpenpyxlReader.get_sheet_by_name(self, name)
#     581 def get_sheet_by_name(self, name: str):
# --> 582     self.raise_if_bad_sheet_by_name(name)
#     583     return self.book[name]
#
# File c:\Users\dhira\Desktop\GEN_AI_PROJECT\env\Lib\site-packages\pandas\io\excel\_base.py:624, in BaseExcelReader.raise_if_bad_sheet_by_name(self, name)
#     622 def raise_if_bad_sheet_by_name(self, name: str) -> None:
#     623     if name not in self.sheet_names:
# --> 624         raise ValueError(f"Worksheet named '{name}' not found")
#
# ValueError: Worksheet named 'peoplebasic' not found

# %% [markdown]
# **Multiple Sheets at Once**

# %%
# Import pandas library — used for data analysis and Excel file handling
import pandas as pd

# Define the path to the Excel file containing multiple sheets.
# The 'r' before the string makes it a raw string so backslashes are treated literally.
people_basic_sheet = r"C:\Users\dhira\Desktop\GEN_AI_PROJECT\pandas\01_Foundation\dataset\raw\people_basic_data.xlsx"

# Read all sheets from the Excel file into a dictionary of DataFrames.
# Setting sheet_name=None tells pandas to read *every* sheet in the file.
# The resulting object is a dictionary where:
#   - Keys = sheet names
#   - Values = DataFrames containing the data from each sheet
dfs_multi_sheet = pd.read_excel(people_basic_sheet, sheet_name=None)

# Print the keys (sheet names) of the dictionary.
# This shows which sheets were loaded from the Excel file.
print(dfs_multi_sheet.keys())
# Out:
# dict_keys(['peoplebasic'])

# %% [markdown]
# **🧩 Reading JSON Files**

# %%
# Import pandas library — required for handling JSON, Excel, CSV, and other data formats
import pandas as pd

# Define the path to the JSON file.
# The 'r' prefix makes it a raw string literal, so backslashes are treated literally (useful for Windows paths).
sales_json = r"C:\Users\dhira\Desktop\GEN_AI_PROJECT\pandas\01_Foundation\dataset\raw\sales_data.json"

# Read the JSON file into a pandas DataFrame.
# pd.read_json() automatically converts JSON structures (like arrays or objects) into tabular format.
# The JSON file should contain a valid structure such as:
# [
#   {"date": "2025-01-01", "sales": 200, "region": "North"},
#   {"date": "2025-01-02", "sales": 250, "region": "South"}
# ]
df_json = pd.read_json(sales_json)

# Display the DataFrame to verify that the JSON data was loaded correctly.
print(df_json)
# Out:
#     Order_ID Customer_ID Customer_Name Region Country Product_ID  \
# 0   ORD-0001    CUST-033         Aarav  North      UK   PROD-071
# 1   ORD-0002    CUST-028          Emma  North     USA   PROD-140
# 2   ORD-0003    CUST-004          Ravi   East   India   PROD-136
# 3   ORD-0004    CUST-020          Emma   East  Canada   PROD-197
# 4   ORD-0005    CUST-009         David  South      UK   PROD-066
# ..       ...         ...           ...    ...     ...        ...
# 95  ORD-0096    CUST-028          Ravi   East     USA   PROD-060
# 96  ORD-0097    CUST-019        Sophia   West   India   PROD-022
# 97  ORD-0098    CUST-006         Kevin  South  Canada   PROD-179
# 98  ORD-0099    CUST-040         David   West   India   PROD-048
# 99  ORD-0100    CUST-028          Emma   West   India   PROD-107
#
#            Category Sub_Category            Product_Name  Order_Date  \
# 0   Office Supplies          Pen         Pen - Model 193  2024-07-10
# 1         Furniture        Chair       Chair - Model 968  2024-02-05
# 2         Furniture     Bookcase    Bookcase - Model 587  2024-05-14
# 3   Office Supplies      Stapler     Stapler - Model 746  2024-09-04
# 4         Furniture        Table       Table - Model 634  2024-07-11
# ..              ...          ...                     ...         ...
# 95       Technology   Headphones  Headphones - Model 906  2024-11-05
# 96       Technology      Printer     Printer - Model 315  2024-04-29
# 97        Furniture        Chair       Chair - Model 567  2024-06-23
# 98        Furniture     Bookcase    Bookcase - Model 315  2024-08-24
# 99        Furniture         Sofa        Sofa - Model 856  2024-04-19
#
#     Quantity  Unit_Price  Total_Sales  Discount   Profit  Year      Month
# 0          9        4057     34687.35      0.05  3387.65  2024       July
# 1          8        4331     29450.80      0.15  5840.76  2024   February
# 2          7        2842     17904.60      0.10  1520.96  2024        May
# 3          2        4080      6936.00      0.15   696.26  2024  September
# 4          7        3402     21432.60      0.10  4720.46  2024       July
# ..       ...         ...          ...       ...      ...   ...        ...
# 95         2        4674      9348.00      0.00  1177.22  2024   November
# 96         3        2489      6720.30      0.10  1278.36  2024      April
# 97         8        3390     25764.00      0.05  2672.85  2024       June
# 98         7        4267     26882.10      0.10  5113.17  2024     August
# 99         4        3400     12920.00      0.05  1296.47  2024      April
#
# [100 rows x 17 columns]

# %% [markdown]
# **🧩 Reading Data from URLs or APIs**

# %%
# Import pandas library — required for reading CSV files and data manipulation
import pandas as pd

# Define the URL of the CSV file.
# This file is hosted online on GitHub and contains the famous Iris dataset.
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"

# Read the CSV file directly from the URL into a pandas DataFrame.
# pd.read_csv() can handle both local file paths and URLs.
df = pd.read_csv(url)

# Display the first 5 rows of the DataFrame.
# This gives a quick overview of the dataset's structure and contents.
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
import requests

url = "https://data.wa.gov/api/views/f6w7-q2d2/rows.json?accessType=DOWNLOAD"


response = requests.get(url)
invest_data = response.json()

rows = invest_data['data']

columns = [col['name'] for col in invest_data['meta']['view']['columns']]

df = pd.DataFrame(rows, columns=columns)
print(df.head)
# Out:
# <bound method NDFrame.head of                        sid                                    id  position  \
# 0       row-9zmh-kxbg.u7ht  00000000-0000-0000-D2B6-825AE6F8F1CE         0
# 1       row-37k7-e7fd.ke3a  00000000-0000-0000-E2D8-EA9DF85F3D8A         0
# 2       row-6tqu_bbkp-svcy  00000000-0000-0000-F9FE-B94525DD352F         0
# 3       row-a9tb.fs47_7guu  00000000-0000-0000-DBD6-06DE43567716         0
# 4       row-pnnp-rdrk_2tq7  00000000-0000-0000-10FC-57C1DAA2F1DF         0
# ...                    ...                                   ...       ...
# 264623  row-emkp.wbxj-x5if  00000000-0000-0000-4347-29B94EE1B336         0
# 264624  row-vxne.ssid.3q46  00000000-0000-0000-D301-B5935F31BA59         0
# 264625  row-enpg~ga9v-az63  00000000-0000-0000-8683-1D9C52569B86         0
# 264626  row-gii8.hmzj.kysr  00000000-0000-0000-DE47-89235328C85D         0
# 264627  row-csn6.n4ji~h4di  00000000-0000-0000-215B-D56AFB9B3250         0
#
#         created_at created_meta  updated_at updated_meta meta  VIN (1-10)  \
# 0       1760391073         None  1760391201         None  { }  WA1E2AFY8R
# 1       1760391073         None  1760391201         None  { }  WAUUPBFF4J
# 2       1760391073         None  1760391201         None  { }  1N4AZ0CP0F
# 3       1760391073         None  1760391201         None  { }  WA1VAAGE5K
# 4       1760391073         None  1760391201         None  { }  7SAXCAE57N
# ...            ...          ...         ...          ...  ...         ...
# 264623  1760391073         None  1760391251         None  { }  KM8KRDDF7R
# 264624  1760391073         None  1760391251         None  { }  1N4BZ0CPXG
# 264625  1760391073         None  1760391251         None  { }  7SAYGDEE4P
# 264626  1760391073         None  1760391251         None  { }  5YJYGDEE9M
# 264627  1760391073         None  1760391251         None  { }  7SAYGDEE9S
#
#            County  ... Electric Range Base MSRP Legislative District  \
# 0        Thurston  ...             23         0                   22
# 1          Yakima  ...             16         0                   15
# 2            King  ...             84         0                   46
# 3            King  ...            204         0                   11
# 4       Snohomish  ...              0         0                    1
# ...           ...  ...            ...       ...                  ...
# 264623       King  ...              0         0                   45
# 264624       King  ...             84         0                   36
# 264625       King  ...              0         0                   11
# 264626       King  ...              0         0                   48
# 264627       King  ...              0         0                   41
#
#        DOL Vehicle ID             Vehicle Location  \
# 0           263239938   POINT (-122.90787 46.9461)
# 1           318160860  POINT (-120.42083 46.44779)
# 2           184963586  POINT (-122.30253 47.72656)
# 3           259426821  POINT (-122.17743 47.41185)
# 4           208182236   POINT (-122.18384 47.8031)
# ...               ...                          ...
# 264623      274603444  POINT (-122.02054 47.60326)
# 264624      476696867  POINT (-122.40092 47.65908)
# 264625      231020723  POINT (-122.16335 47.53505)
# 264626      139826809  POINT (-122.13158 47.67858)
# 264627      275985356   POINT (-122.1872 47.61001)
#
#                                      Electric Utility 2020 Census Tract  \
# 0                              PUGET SOUND ENERGY INC       53067010910
# 1                                          PACIFICORP       53077940008
# 2        CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       53033000700
# 3       PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       53033029306
# 4                              PUGET SOUND ENERGY INC       53061051922
# ...                                               ...               ...
# 264623  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       53033032225
# 264624   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       53033005803
# 264625  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       53033025602
# 264626  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       53033022902
# 264627  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       53033023808
#
#        Counties Congressional Districts  \
# 0          2742                      10
# 1          2746                       4
# 2          3009                       7
# 3          3009                       9
# 4          3213                       1
# ...         ...                     ...
# 264623     3009                       8
# 264624     3009                       7
# 264625     3009                       9
# 264626     3009                       1
# 264627     3009                       9
#
#        WAOFM - GIS - Legislative District Boundary
# 0                                               39
# 1                                               22
# 2                                               48
# 3                                               46
# 4                                                1
# ...                                            ...
# 264623                                          47
# 264624                                          31
# 264625                                          42
# 264626                                          49
# 264627                                          42
#
# [264628 rows x 28 columns]>

# %% [markdown]
# **🧩 Writing (Exporting) Data**

# %%
df_expo = df.to_csv(r"C:\Users\dhira\Desktop\GEN_AI_PROJECT\pandas\01_Foundation\dataset\cleaned\superstore_sales_cleaned.csv", index=False)

print(df_expo)
# Out:
# None

# %% [markdown]
# **Write to Excel**

# %%
# Import pandas library — required for data manipulation and exporting data
import pandas as pd

# Assuming 'df' is the cleaned sales DataFrame that you want to export

# Reset the index of the DataFrame.
# drop=True ensures that the old index is removed and not added as a column.
df_reset = df.reset_index(drop=True)

# Export the cleaned DataFrame to an Excel file.
# The 'index=False' argument prevents the DataFrame's index from being written to the file.
# This saves the DataFrame to the specified path without the index column, which is often not needed in the output.
df_reset.to_excel(r"C:\Users\dhira\Desktop\GEN_AI_PROJECT\pandas\01_Foundation\dataset\cleaned\people_basic_data.xlsx", index=False)

# Print the cleaned DataFrame to verify the changes before saving
print(df_reset)
# Out:
#            Date     Product  Units  UnitPrice  Revenue
# 0    2024-01-01     Monitor     46       1999    91954
# 1    2024-01-02    Keyboard      8       9999    79992
# 2    2024-01-03  Headphones     25        999    24975
# 3    2024-01-04     Monitor     35      14999   524965
# 4    2024-01-05  Headphones     25       2999    74975
# ..          ...         ...    ...        ...      ...
# 115  2024-04-25  Headphones     26       4999   129974
# 116  2024-04-26    Keyboard     42      14999   629958
# 117  2024-04-27      Laptop     22        999    21978
# 118  2024-04-28     Monitor     14       1999    27986
# 119  2024-04-29       Mouse      2       2999     5998
#
# [120 rows x 5 columns]

# %% [markdown]
# **Write to JSON**

# %%
# Import pandas library — necessary for data manipulation and file export
import pandas as pd

# Reset the index of the DataFrame.
# drop=True ensures that the old index is not included as a column in the new DataFrame.
df_reset = df.reset_index(drop=True)

# Export the cleaned DataFrame to a JSON file.
# The 'orient' argument is set to 'records', which converts each row into a dictionary format.
# 'indent=2' makes the output more human-readable by adding indents for readability (useful for debugging or sharing).
df_reset.to_json(r"C:\Users\dhira\Desktop\GEN_AI_PROJECT\pandas\01_Foundation\dataset\cleaned\sales_data.json", orient='records', indent=2)

# Print the cleaned DataFrame to verify the changes before saving
print(df_reset)
# Out:
#            Date     Product  Units  UnitPrice  Revenue
# 0    2024-01-01     Monitor     46       1999    91954
# 1    2024-01-02    Keyboard      8       9999    79992
# 2    2024-01-03  Headphones     25        999    24975
# 3    2024-01-04     Monitor     35      14999   524965
# 4    2024-01-05  Headphones     25       2999    74975
# ..          ...         ...    ...        ...      ...
# 115  2024-04-25  Headphones     26       4999   129974
# 116  2024-04-26    Keyboard     42      14999   629958
# 117  2024-04-27      Laptop     22        999    21978
# 118  2024-04-28     Monitor     14       1999    27986
# 119  2024-04-29       Mouse      2       2999     5998
#
# [120 rows x 5 columns]

# %% [markdown]
# **🧩 Reading/Writing from SQL (Preview)**

# %%
# import sqlite3
# conn = sqlite3.connect('../datasets/raw/sample.db')

# df = pd.read_sql("SELECT * FROM sales", conn)
# df.to_sql('cleaned_sales', conn, if_exists='replace', index=False)
# conn.close()

# %% [markdown]
# **🧩 Mini Project — “Data I/O Pipeline**

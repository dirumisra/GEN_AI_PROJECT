# %% [markdown]
# ### **🧩 Objective**
# - Install all core GenAI libraries safely inside your environment (e.g., conda or venv).

# %%
# Optional but recommended
# !pip install faiss-cpu sentence-transformers tabulate requests

# %%
# Base GenAI + Data stack
# !pip install openai langchain chromadb tiktoken streamlit python-dotenv pydantic
